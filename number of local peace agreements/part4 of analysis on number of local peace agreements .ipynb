# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("MEDIATORPER.csv")
data
# Out:
#    Year  Libya  South Sudan  Syria  Yemen  Libyam  South Sudanm  Syriam  \
# 0  2011      0            1      0      0       0             1       0
# 1  2012      0            1      1      0       0             1       1
# 2  2013      0            1      3      0       0             0       1
# 3  2014      0            3      8     14       0             3       3
# 4  2015      5            2     10      2       0             2       3
# 5  2016      6            1     13      5       4             1       3
# 6  2017      6            5     23      0       3             4      10
# 7  2018     14            2     14      2       2             2       6
# 8  2019      1            3      3      2       0             3       0
# 9  2020      0            1      0      0       0             1       0
#
#    Yemenm    Libyap  South Sudanp    Syriap    Yemenp
# 0       0  0.000000           1.0  0.000000  0.000000
# 1       0  0.000000           1.0  1.000000  0.000000
# 2       0  0.000000           0.0  0.333333  0.000000
# 3      11  0.000000           1.0  0.375000  0.785714
# 4       2  0.000000           1.0  0.300000  1.000000
# 5       2  0.666667           1.0  0.230769  0.400000
# 6       0  0.500000           0.8  0.434783  0.000000
# 7       2  0.142857           1.0  0.428571  1.000000
# 8       2  0.000000           1.0  0.000000  1.000000
# 9       0  0.000000           1.0  0.000000  0.000000

# %%
data = data.set_index("Year",inplace = False)

# %%
data[["Libyap","South Sudanp","Syriap","Yemenp"]].plot(kind='line', figsize=(10, 4))
